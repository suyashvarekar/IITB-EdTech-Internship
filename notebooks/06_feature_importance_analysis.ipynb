# %% [markdown]
# RandomForest - Feature Importance

# %%
if y is not None:
    rf = RandomForestClassifier(n_estimators=200, random_state=42)
    rf.fit(X_scaled, y)
    importances = rf.feature_importances_
    feat_names = X_clean.columns
    importance_df = pd.DataFrame({"Feature": feat_names, "Importance": importances}).sort_values("Importance", ascending=False)
    importance_df.to_csv("project/models/feature_importance.csv", index=False)
    print("Saved feature_importance.csv")
else:
    print("Skipped RF importance - no labels")
# Out:
# Saved feature_importance.csv

# %%
if 'importance_df' in locals() and y is not None:
    plt.figure(figsize=(8,6))
    sns.barplot(x="Importance", y="Feature", data=importance_df.head(20), palette="viridis")
    plt.title("Top 20 Most Important Features")
    plt.show()

    # Print top 10 features in text
    print("Top 10 Important Features:")
    print(importance_df.head(10))
else:
    print("Skipped Feature Importance (no labels).")
# Out:
# /tmp/ipython-input-1458023187.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Importance", y="Feature", data=importance_df.head(20), palette="viridis")
# Top 10 Important Features:
#                        Feature  Importance
# 117             IVT_Gaze X_std    0.025578
# 1           EEG_Delta_TP9_mean    0.021202
# 13         EEG_Delta_TP10_mean    0.015880
# 26          EEG_Alpha_TP9_mean    0.014957
# 40            EEG_Beta_AF7_min    0.012915
# 193      EYE_ET_PupilLeft_mean    0.012710
# 153  IVT_Fixation Duration_min    0.012692
# 102            EEG_HSI_TP9_std    0.012574
# 161      IVT_Saccade Start_std    0.012103
# 332         TIVA_BlinkRate_max    0.011916
